# %%
import geoai

# %%
directory = "Training Data"
geoai.train_segmentation_model(
    images_dir=f"{directory}/nasa_patches_split",
    labels_dir=f"{directory}/nasa_masks_split",
    output_dir=f"{directory}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=9,
    num_classes=2,  # background and water
    batch_size=4,
    num_epochs=3,  # training for 3 epochs to save time, in practice you should train for more epochs
    learning_rate=1e-4,
    val_split=0.2,
    verbose=True,
)
# Out:
# Using device: cpu
# Found 184 image files and 184 label files
# Training on 147 images, validating on 37 images
# Checking image sizes for compatibility...
# Warning: Found images with different sizes: [(530, 540), (538, 503)]
# Setting target_size to (512, 512) to standardize image dimensions.
# This will resize all images to 512x512 pixels.
# To use a different size, set target_size parameter explicitly.
# Testing data loader...
# Data loader test passed.
# Starting training with unet + resnet34
# Model parameters: 24,455,330
# Epoch: 1, Batch: 1/37, Loss: 0.3931, Time: 9.40s
# Epoch: 1, Batch: 11/37, Loss: nan, Time: 108.94s
# Epoch: 1, Batch: 21/37, Loss: nan, Time: 94.37s
# Epoch: 1, Batch: 31/37, Loss: nan, Time: 104.35s
# Epoch 1/3: Train Loss: nan, Val Loss: nan, Val IoU: 0.6992, Val F1: 0.7009, Val Precision: 0.9930, Val Recall: 0.7027
# Saving best model with IoU: 0.6992
# Epoch: 2, Batch: 1/37, Loss: nan, Time: 11.07s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 directory = "Training Data"
# ----> 2 geoai.train_segmentation_model(
#       3     images_dir=f"{directory}/nasa_patches_split",
#       4     labels_dir=f"{directory}/nasa_masks_split",
#       5     output_dir=f"{directory}/unet_models",
#       6     architecture="unet",
#       7     encoder_name="resnet34",
#       8     encoder_weights="imagenet",
#       9     num_channels=9,
#      10     num_classes=2,  # background and water
#      11     batch_size=4,
#      12     num_epochs=3,  # training for 3 epochs to save time, in practice you should train for more epochs
#      13     learning_rate=1e-4,
#      14     val_split=0.2,
#      15     verbose=True,
#      16 )
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\geoai\train.py:2761, in train_segmentation_model(images_dir, labels_dir, output_dir, input_format, architecture, encoder_name, encoder_weights, num_channels, num_classes, batch_size, num_epochs, learning_rate, weight_decay, seed, val_split, print_freq, verbose, save_best_only, plot_curves, device, checkpoint_path, resume_training, target_size, resize_mode, num_workers, early_stopping_patience, **kwargs)
#    2758 # Training loop
#    2759 for epoch in range(start_epoch, num_epochs):
#    2760     # Train one epoch
# -> 2761     train_loss = train_semantic_one_epoch(
#    2762         model,
#    2763         optimizer,
#    2764         train_loader,
#    2765         device,
#    2766         epoch,
#    2767         criterion,
#    2768         print_freq,
#    2769         verbose,
#    2770     )
#    2771     train_losses.append(train_loss)
#    2773     # Evaluate on validation set
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\geoai\train.py:2270, in train_semantic_one_epoch(model, optimizer, data_loader, device, epoch, criterion, print_freq, verbose)
#    2267 targets = targets.to(device)
#    2269 # Forward pass
# -> 2270 outputs = model(images)
#    2271 loss = criterion(outputs, targets)
#    2273 # Backward pass
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\segmentation_models_pytorch\base\model.py:66, in SegmentationModel.forward(self, x)
#      61 if not (
#      62     torch.jit.is_scripting() or torch.jit.is_tracing() or is_torch_compiling()
#      63 ):
#      64     self.check_input_shape(x)
# ---> 66 features = self.encoder(x)
#      67 decoder_output = self.decoder(features)
#      69 masks = self.segmentation_head(decoder_output)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\segmentation_models_pytorch\encoders\resnet.py:76, in ResNetEncoder.forward(self, x)
#      73     features.append(x)
#      75 if self._depth >= 3:
# ---> 76     x = self.layer2(x)
#      77     features.append(x)
#      79 if self._depth >= 4:
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\resnet.py:92, in BasicBlock.forward(self, x)
#      89 def forward(self, x: Tensor) -> Tensor:
#      90     identity = x
# ---> 92     out = self.conv1(x)
#      93     out = self.bn1(out)
#      94     out = self.relu(out)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\eagle\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
# Performance statistics
geoai.plot_performance_metrics(
    history_path=f"{directory}/unet_models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)
